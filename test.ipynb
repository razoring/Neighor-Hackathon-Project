# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# False

# %%
# --- SET FFMPEG PATH ---
# Add WinGet links to PATH for pydub to find ffmpeg
import os


winget_path = r"C:\Users\conta\AppData\Local\Microsoft\WinGet\Links"
if winget_path not in os.environ.get("PATH", ""):
    os.environ["PATH"] = winget_path + os.pathsep + os.environ.get("PATH", "")
